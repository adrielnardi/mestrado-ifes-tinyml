# %%
import matplotlib.pyplot as plt

# Valores do dado e suas frequências
valores = [96, 94, 65, 87, 78, 70, 98, 93, 97, 83, 69, 95, 89, 73, 76, 92, 84, 91, 71, 66, 79, 88, 80, 81, 77, 75, 68, 74, 67, 72, 82, 86, 99, 63, 90, 85]
frequencias = [16, 13, 5, 8, 2, 9, 2, 4, 9, 8, 10, 17, 5, 3, 5, 9, 6, 3, 8, 5, 1, 3, 5, 9, 4, 6, 6, 4, 10, 4, 3, 3, 1, 1, 1, 1]

# Total de observações
total_observacoes = sum(frequencias)

# Calculando as frequências relativas
frequencias_relativas = [freq / total_observacoes for freq in frequencias]

# Definindo o tamanho da figura
plt.figure(figsize=(12, 6))  # Altere largura e altura conforme necessário

# Criando o gráfico de barras
plt.bar(valores, frequencias_relativas, align='center', alpha=0.7, color='skyblue')

plt.xlabel('Assertividade Detecção de Pessoa')
plt.ylabel('Frequência Relativa')
plt.title('Distribuição de Probabilidade - Rodada 01')
plt.xticks(valores)  # Define os valores no eixo x
plt.show()

# %%
import matplotlib.pyplot as plt

# Valores do dado e suas frequências
valores = [100, 75, 71, 70, 74, 90, 79, 72, 76, 80, 69, 86, 87, 64, 91, 88, 85, 81, 93, 92, 68, 66, 73, 95, 94, 65, 89, 78, 96, 67, 99, 82, 83, 84, 77, 63, 98]
frequencias = [1, 4, 5, 6, 4, 3, 2, 7, 5, 6, 5, 5, 8, 2, 7, 5, 7, 4, 9, 5, 6, 2, 3, 3, 5, 4, 7, 7, 1, 5, 1, 5, 4, 2, 3, 2, 1]

# Total de observações
total_observacoes = sum(frequencias)

# Calculando as frequências relativas
frequencias_relativas = [freq / total_observacoes for freq in frequencias]

# Definindo o tamanho da figura
plt.figure(figsize=(12, 6))  # Altere largura e altura conforme necessário

# Criando o gráfico de barras
plt.bar(valores, frequencias_relativas, align='center', alpha=0.7, color='lightgreen')

plt.xlabel('Assertividade Detecção de Pessoa')
plt.ylabel('Frequência Relativa')
plt.title('Distribuição de Probabilidade - Rodada 02')
plt.xticks(valores)  # Define os valores no eixo x
plt.show()

# %%
import matplotlib.pyplot as plt

# Valores do dado e suas frequências
valores = [96, 90, 89, 79, 67, 73, 74, 75, 81, 80, 88, 77, 85, 76, 70, 66, 83, 86, 68, 69, 65, 84, 72, 71, 94, 95, 92, 93, 87, 78, 64, 82]
frequencias = [2, 4, 2, 10, 12, 11, 10, 3, 14, 10, 4, 8, 6, 12, 11, 10, 7, 2, 9, 11, 9, 4, 9, 8, 3, 1, 1, 2, 4, 10, 2, 1]

# Total de observações
total_observacoes = sum(frequencias)

# Calculando as frequências relativas
frequencias_relativas = [freq / total_observacoes for freq in frequencias]

# Definindo o tamanho da figura
plt.figure(figsize=(12, 6))  # Altere largura e altura conforme necessário

# Criando o gráfico de barras
plt.bar(valores, frequencias_relativas, align='center', alpha=0.7, color='magenta')

plt.xlabel('Assertividade Detecção de Pessoa')
plt.ylabel('Frequência Relativa')
plt.title('Distribuição de Probabilidade - Rodada 03')
plt.xticks(valores)  # Define os valores no eixo x
plt.show()

# %%
import matplotlib.pyplot as plt

# Valores do dado e suas frequências
valores = [76, 89, 94, 87, 80, 79, 72, 88, 78, 70, 81, 67, 66, 73, 68, 86, 85, 83, 84, 69, 96, 71, 65, 74, 90, 75, 92, 77, 82, 95, 64, 93, 91, 97, 100, 98]
frequencias = [12, 14, 10, 7, 19, 5, 23, 5, 13, 20, 13, 21, 9, 7, 13, 8, 5, 8, 3, 17, 3, 11, 12, 12, 6, 5, 3, 9, 4, 4, 1, 2, 1, 1, 1, 1]

# Total de observações
total_observacoes = sum(frequencias)

# Calculando as frequências relativas
frequencias_relativas = [freq / total_observacoes for freq in frequencias]

# Definindo o tamanho da figura
plt.figure(figsize=(12, 6))  # Altere largura e altura conforme necessário

# Criando o gráfico de barras
plt.bar(valores, frequencias_relativas, align='center', alpha=0.7, color='lightcoral')

plt.xlabel('Assertividade Detecção de Pessoa')
plt.ylabel('Frequência Relativa')
plt.title('Distribuição de Probabilidade - Rodada 04')
plt.xticks(valores)  # Define os valores no eixo x
plt.show()

# %%
from collections import Counter

# Sequência de valores fornecida
sequence = ''' 76, 89, 94, 89, 89, 87, 80, 79, 72, 88, 89, 78, 70, 81, 67, 66, 67, 73, 68, 80, 86,
    81, 85, 83, 84, 67, 69, 96, 69, 71, 65, 69, 74, 69, 71, 68, 67, 87, 90, 78, 85, 74,
    83, 65, 66, 75, 78, 80, 83, 88, 89, 84, 92, 92, 81, 75, 90, 83, 85, 84, 77, 87, 85,
    80, 66, 80, 78, 89, 86, 81, 78, 68, 94, 73, 74, 89, 79, 86, 83, 80, 81, 86, 86, 80,
    81, 86, 88, 87, 82, 80, 80, 83, 82, 72, 81, 79, 76, 80, 78, 77, 70, 79, 77, 76, 72,
    78, 81, 67, 70, 69, 95, 67, 71, 69, 67, 66, 76, 70, 72, 96, 74, 76, 77, 74, 89, 87,
    81, 80, 80, 82, 76, 81, 94, 72, 78, 75, 74, 73, 76, 80, 75, 76, 72, 71, 70, 88, 74,
    69, 72, 72, 68, 80, 68, 69, 74, 67, 67, 70, 71, 65, 69, 71, 72, 68, 72, 66, 66, 73,
    67, 77, 78, 81, 72, 78, 77, 76, 69, 67, 74, 67, 70, 67, 67, 69, 70, 66, 77, 69, 89,
    65, 86, 77, 68, 89, 80, 72, 73, 78, 92, 94, 72, 89, 76, 94, 95, 94, 71, 71, 65, 80,
    79, 75, 72, 72, 72, 70, 66, 68, 81, 65, 69, 66, 65, 65, 72, 70, 70, 67, 71, 67, 67,
    68, 69, 68, 70, 70, 72, 71, 94, 70, 68, 72, 72, 67, 67, 67, 70, 72, 70, 76, 71, 69,
    65, 70, 73, 65, 76, 74, 90, 70, 64, 89, 70, 77, 81, 68, 74, 94, 82, 72, 73, 78, 65,
    70, 78, 86, 88, 83, 90, 65, 83, 95, 80, 68, 69, 80, 80, 90, 87, 89, 89, 94, 93, 91,
    67, 85, 87, 69, 97, 94, 74, 95, 90, 72, 93, 96, 100, 98'''

# Removendo espaços e quebras de linha extras
clean_sequence = sequence.replace('\n', '').replace(' ', '')

# Convertendo a string para uma lista de inteiros
values = list(map(int, clean_sequence.split(',')))

# Contando as frequências dos valores
freq_counter = Counter(values)

# Separando os valores únicos e suas frequências
unique_values = list(freq_counter.keys())
frequencies = list(freq_counter.values())

# Imprimindo os valores únicos e suas frequências
print("valores =", unique_values)
print("frequencias =", frequencies)
# Out:
# valores = [76, 89, 94, 87, 80, 79, 72, 88, 78, 70, 81, 67, 66, 73, 68, 86, 85, 83, 84, 69, 96, 71, 65, 74, 90, 75, 92, 77, 82, 95, 64, 93, 91, 97, 100, 98]
# frequencias = [12, 14, 10, 7, 19, 5, 23, 5, 13, 20, 13, 21, 9, 7, 13, 8, 5, 8, 3, 17, 3, 11, 12, 12, 6, 5, 3, 9, 4, 4, 1, 2, 1, 1, 1, 1]
